# %% [markdown]
# # **Checkpoint 2**

# %%
import pandas as pd

file_path ="/content/drive/MyDrive/praktikum avd/BMIData.csv"

df=pd.read_csv(file_path)

df.head()
# Out:
#    SchoolYear NameHospital     Sex  EpiUnderweight  EpiHealthyWeight  \
# 0        2001      Borders  Female               2               334
# 1        2001      Borders    Male               5               301
# 2        2001      Lothian  Female              12               728
# 3        2001      Lothian    Male              17               681
# 4        2001         Fife  Female              17              1361
#
#    EpiOverweight  EpiObese  EpiOverweightAndObese  ValidCounts  UnvalidCounts  \
# 0             54        28                     82          418             82
# 1             63        42                    105          411            105
# 2            133       106                    239          979            239
# 3            124       114                    238          936            238
# 4            231       155                    386         1764            386
#
#    TotalCounts
# 0          500
# 1          516
# 2         1218
# ...

# %%
import pandas as pd

# %% [markdown]
# # **Data Understanding**
#
#
# Dataset ini diperoleh dari Kaggle-klasifikasi berat badan anak.

# %%
df = pd.read_csv("/content/drive/MyDrive/praktikum avd/BMIData.csv")

# %% [markdown]
# **1. Cek jumlah baris dan kolom**
#
# Dataset memiliki 516 baris dan 11 kolom.

# %%
print("Jumlah baris dan kolom:", df.shape)
# Out:
# Jumlah baris dan kolom: (516, 11)

# %% [markdown]
# **2. Cek tipe data setiap kolom**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SchoolYear             516 non-null    int64
#  1   NameHospital           516 non-null    object
#  2   Sex                    516 non-null    object
#  3   EpiUnderweight         516 non-null    int64
#  4   EpiHealthyWeight       516 non-null    int64
#  5   EpiOverweight          516 non-null    int64
#  6   EpiObese               516 non-null    int64
#  7   EpiOverweightAndObese  516 non-null    int64
#  8   ValidCounts            516 non-null    int64
#  9   UnvalidCounts          516 non-null    int64
#  10  TotalCounts            516 non-null    int64
# dtypes: int64(9), object(2)
# memory usage: 44.5+ KB

# %% [markdown]
# **3. Tampilkan 5 data pertama dan terakhir untuk melihat isi dataset (jika baris banyak)**

# %%
df
# Out:
#      SchoolYear               NameHospital     Sex  EpiUnderweight  \
# 0          2001                    Borders  Female               2
# 1          2001                    Borders    Male               5
# 2          2001                    Lothian  Female              12
# 3          2001                    Lothian    Male              17
# 4          2001                       Fife  Female              17
# ..          ...                        ...     ...             ...
# 511        2023                    Tayside    Male              15
# 512        2023  Greater Glasgow and Clyde  Female              34
# 513        2023  Greater Glasgow and Clyde    Male              89
# 514        2023                Lanarkshire  Female              14
# 515        2023                Lanarkshire    Male              31
#
#      EpiHealthyWeight  EpiOverweight  EpiObese  EpiOverweightAndObese  \
# 0                 334             54        28                     82
# ...

# %% [markdown]
# **4. statistik deskriptif**

# %%
df.describe()
# Out:
#         SchoolYear  EpiUnderweight  EpiHealthyWeight  EpiOverweight  \
# count   516.000000      516.000000         516.00000     516.000000
# mean   2013.383721       21.742248        1304.72093     208.102713
# std       5.947672       25.207054        1103.90967     167.192486
# min    2001.000000        0.000000           7.00000       0.000000
# 25%    2009.000000        3.000000         421.75000      66.750000
# 50%    2013.500000       13.000000        1158.50000     196.000000
# 75%    2018.000000       30.000000        1946.25000     292.000000
# max    2023.000000      137.000000        4623.00000     696.000000
#
#          EpiObese  EpiOverweightAndObese  ValidCounts  UnvalidCounts  \
# count  516.000000             516.000000   516.000000     516.000000
# mean   175.563953             383.666667  1710.129845     383.666667
# std    147.842378             313.523071  1433.191567     313.523071
# min      2.000000               2.000000    10.000000       2.000000
# ...

# %% [markdown]
# ## **Data Preparation**
#
# Dataset ini diperoleh dari Kaggle-klasifikasi berat badan anak.

# %% [markdown]
# # **A.Pengecekan Terhadap Data**

# %% [markdown]
# **1. nilai yang hilang (Missing Values)**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# SchoolYear               0.0
# NameHospital             0.0
# Sex                      0.0
# EpiUnderweight           0.0
# EpiHealthyWeight         0.0
# EpiOverweight            0.0
# EpiObese                 0.0
# EpiOverweightAndObese    0.0
# ValidCounts              0.0
# UnvalidCounts            0.0
# TotalCounts              0.0
# dtype: float64

# %% [markdown]
# **2. Duplicated Values**

# %%
duplicate_rows = df[df.duplicated()]
print("\nJumlah Baris Duplikat:", len(duplicate_rows))
# Out:
# Jumlah Baris Duplikat: 0

# %% [markdown]
# **3. Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                  Persentase Outliers
# SchoolYear                        0.000000
# EpiUnderweight                    6.589147
# EpiHealthyWeight                  2.713178
# EpiOverweight                     2.713178
# EpiObese                          3.682171
# EpiOverweightAndObese             2.713178
# ValidCounts                       2.906977
# UnvalidCounts                     2.713178
# TotalCounts                       2.906977

# %%
df
# Out:
#      SchoolYear               NameHospital     Sex  EpiUnderweight  \
# 0          2001                    Borders  Female               2
# 1          2001                    Borders    Male               5
# 2          2001                    Lothian  Female              12
# 3          2001                    Lothian    Male              17
# 4          2001                       Fife  Female              17
# ..          ...                        ...     ...             ...
# 511        2023                    Tayside    Male              15
# 512        2023  Greater Glasgow and Clyde  Female              34
# 513        2023  Greater Glasgow and Clyde    Male              89
# 514        2023                Lanarkshire  Female              14
# 515        2023                Lanarkshire    Male              31
#
#      EpiHealthyWeight  EpiOverweight  EpiObese  EpiOverweightAndObese  \
# 0                 334             54        28                     82
# ...

# %% [markdown]
# **4. Incosistent Value**
#
# Menurut Saya, dataset yang saya teliti tidak ada nilai yang tidak konsisten

# %% [markdown]
# ## **B. Penanganan terhadap Data**

# %% [markdown]
# **1. nilai yang hilang (Missing Values)**
#
#       tidak ada nilai yang hilang

# %%
missing_values = df.isnull().sum()

# %% [markdown]
# **2. Duplicated Values (Dihapus semua duplikasi)**

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      SchoolYear               NameHospital     Sex  EpiUnderweight  \
# 0          2001                    Borders  Female               2
# 1          2001                    Borders    Male               5
# 2          2001                    Lothian  Female              12
# 3          2001                    Lothian    Male              17
# 4          2001                       Fife  Female              17
# ..          ...                        ...     ...             ...
# 511        2023                    Tayside    Male              15
# 512        2023  Greater Glasgow and Clyde  Female              34
# 513        2023  Greater Glasgow and Clyde    Male              89
# 514        2023                Lanarkshire  Female              14
# 515        2023                Lanarkshire    Male              31
#
#      EpiHealthyWeight  EpiOverweight  EpiObese  EpiOverweightAndObese  \
# 0                 334             54        28                     82
# ...

# %% [markdown]
# **3. Outliers (Melakukan imputasi)**

# %%
def impute_outliers(col):
    median = col.median()
    return col.apply(lambda x: median if x < lower_bound[col.name] or x > upper_bound[col.name] else x)

# %% [markdown]
# Melakukan cek ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                  Persentase Outliers
# SchoolYear                        0.000000
# EpiUnderweight                    6.589147
# EpiHealthyWeight                  2.713178
# EpiOverweight                     2.713178
# EpiObese                          3.682171
# EpiOverweightAndObese             2.713178
# ValidCounts                       2.906977
# UnvalidCounts                     2.713178
# TotalCounts                       2.906977

# %%
df
# Out:
#      SchoolYear               NameHospital     Sex  EpiUnderweight  \
# 0          2001                    Borders  Female               2
# 1          2001                    Borders    Male               5
# 2          2001                    Lothian  Female              12
# 3          2001                    Lothian    Male              17
# 4          2001                       Fife  Female              17
# ..          ...                        ...     ...             ...
# 511        2023                    Tayside    Male              15
# 512        2023  Greater Glasgow and Clyde  Female              34
# 513        2023  Greater Glasgow and Clyde    Male              89
# 514        2023                Lanarkshire  Female              14
# 515        2023                Lanarkshire    Male              31
#
#      EpiHealthyWeight  EpiOverweight  EpiObese  EpiOverweightAndObese  \
# 0                 334             54        28                     82
# ...

# %% [markdown]
# **4. Incosistent Value**
#
# Menurut Saya, dataset yang saya teliti tidak ada nilai yang tidak konsisten

# %% [markdown]
# # **konstruksi data (Construct Data) (penambahan kolom)**

# %% [markdown]
# **Menambahkan kolom Persentase Berat Badan Tidak Sehat**

# %%
df["UnhealthyPercentage"] = ((df["EpiUnderweight"] + df["EpiOverweightAndObese"]) / df["TotalCounts"]) * 100

# %%
df
# Out:
#      SchoolYear               NameHospital     Sex  EpiUnderweight  \
# 0          2001                    Borders  Female               2
# 1          2001                    Borders    Male               5
# 2          2001                    Lothian  Female              12
# 3          2001                    Lothian    Male              17
# 4          2001                       Fife  Female              17
# ..          ...                        ...     ...             ...
# 511        2023                    Tayside    Male              15
# 512        2023  Greater Glasgow and Clyde  Female              34
# 513        2023  Greater Glasgow and Clyde    Male              89
# 514        2023                Lanarkshire  Female              14
# 515        2023                Lanarkshire    Male              31
#
#      EpiHealthyWeight  EpiOverweight  EpiObese  EpiOverweightAndObese  \
# 0                 334             54        28                     82
# ...

# %% [markdown]
# **Menambahkan kolom Kategori Risiko Obesitas**

# %%
def categorize_risk(value):
    if value < 10:
        return "Low"
    elif value < 20:
        return "Moderate"
    else:
        return "High"

df["ObesityRiskCategory"] = df["UnhealthyPercentage"].apply(categorize_risk)

# %%
df
# Out:
#      SchoolYear               NameHospital     Sex  EpiUnderweight  \
# 0          2001                    Borders  Female               2
# 1          2001                    Borders    Male               5
# 2          2001                    Lothian  Female              12
# 3          2001                    Lothian    Male              17
# 4          2001                       Fife  Female              17
# ..          ...                        ...     ...             ...
# 511        2023                    Tayside    Male              15
# 512        2023  Greater Glasgow and Clyde  Female              34
# 513        2023  Greater Glasgow and Clyde    Male              89
# 514        2023                Lanarkshire  Female              14
# 515        2023                Lanarkshire    Male              31
#
#      EpiHealthyWeight  EpiOverweight  EpiObese  EpiOverweightAndObese  \
# 0                 334             54        28                     82
# ...

# %% [markdown]
# # **reduksi data (Data Reduction)**

# %% [markdown]
# **menghapus kolom** Mengapa dihapus?
#
#
#
# Dataset lebih ringkas
#
# Mengurangi ukuran file
#
# Fokus pada informasi utama

# %%
columns_to_drop = ["ValidCounts", "UnvalidCounts", "TotalCounts"]
df_cleaned = df.drop(columns=columns_to_drop)

# %%
df
# Out:
#      SchoolYear               NameHospital     Sex  EpiUnderweight  \
# 0          2001                    Borders  Female               2
# 1          2001                    Borders    Male               5
# 2          2001                    Lothian  Female              12
# 3          2001                    Lothian    Male              17
# 4          2001                       Fife  Female              17
# ..          ...                        ...     ...             ...
# 511        2023                    Tayside    Male              15
# 512        2023  Greater Glasgow and Clyde  Female              34
# 513        2023  Greater Glasgow and Clyde    Male              89
# 514        2023                Lanarkshire  Female              14
# 515        2023                Lanarkshire    Male              31
#
#      EpiHealthyWeight  EpiOverweight  EpiObese  EpiOverweightAndObese  \
# 0                 334             54        28                     82
# ...

# %%
df
# Out:
#      SchoolYear               NameHospital     Sex  EpiUnderweight  \
# 0          2001                    Borders  Female               2
# 1          2001                    Borders    Male               5
# 2          2001                    Lothian  Female              12
# 3          2001                    Lothian    Male              17
# 4          2001                       Fife  Female              17
# ..          ...                        ...     ...             ...
# 511        2023                    Tayside    Male              15
# 512        2023  Greater Glasgow and Clyde  Female              34
# 513        2023  Greater Glasgow and Clyde    Male              89
# 514        2023                Lanarkshire  Female              14
# 515        2023                Lanarkshire    Male              31
#
#      EpiHealthyWeight  EpiOverweight  EpiObese  EpiOverweightAndObese  \
# 0                 334             54        28                     82
# ...
